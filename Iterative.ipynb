# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman-286/Software-Engineering-Lab/blob/Task-2/Iterative.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_weather_result(temperature, humidity):
    if not (0 <= humidity <= 100):
        raise ValueError("Humidity should be between 0 and 100 percent.")
    return (0.5 * (temperature ** 2) - 0.2 * humidity - 15) / 0.9


def categorize_weather(result):
    if result > 30:
        return "sunny"
    elif 10 <= result <= 30:
        return "windy"
    else:
        return "rainy"


def main():
    try:
        temperature = float(input("Enter the temperature (in Celsius): "))
        humidity = float(input("Enter the humidity (in percentage): "))
        result = calculate_weather_result(temperature, humidity)
        weather = categorize_weather(result)
        print(f"The weather is: {weather}")
    except ValueError as e:
        print(f"Error: {e}")


if __name__ == "__main__":
    main()
# Out:
# Enter the temperature (in Celsius): 25
# Enter the humidity (in percentage): 0
# The weather is: sunny
